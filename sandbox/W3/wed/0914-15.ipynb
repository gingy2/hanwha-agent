# %%
import streamlit as st
import pandas as pd 
from st_aggrid import AgGrid, GridOptionsBuilder

st.title("AgGrid - 정렬과 필터가 붙은 테이블")

df = pd.DataFrame([
    {"문서ID": "DOC-HR-014", "문서명": "국내출장 여비 규정", "상태": "현행", "청크": 70},
    {"문서ID": "DOC-SE-011", "문서명": "장비 반출입 절차", "상태": "만료", "청크": 24},
    {"문서ID": "DOC-PU-007", "문서명": "구매·계약 규정", "상태": "현행", "청크": 58},
])
# Out:
# 2026-09-16 09:34:35.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-16 09:34:35.710 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-16 09:34:35.834
# ...
#   command:
#
#     streamlit run d:\hanwha-agent\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-09-16 09:34:35.834 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-16 09:34:35.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import streamlit as st
from streamlit_echarts import st_echarts

st.title("Echart - 검색 정확도 게이지 출력")

options = {
    "series": [{
        "type": "gauge", 
        "min": 0, 
        "max": 100, 
        "detail": {"formatter": "{vale}%"}, 
        "data": [{"value": 84, "name": "정확도"}]
    }]
}
# Out:
# ---------------------------------------------------------------------------
# StreamlitAPIException                     Traceback (most recent call last)
# Cell In[3], line 2
#       1 import streamlit as st
# ----> 2 from streamlit_echarts import st_echarts
#       3
#       4 st.title("Echart - 검색 정확도 게이지 출력")
#       5
#
# File d:\hanwha-agent\.venv\Lib\site-packages\streamlit_echarts\__init__.py:13
#       9 import streamlit as st
#      11 __version__ = importlib.metadata.version("streamlit-echarts")
# ---> 13 out = st.components.v2.component(
#      14     "streamlit-echarts.streamlit_echarts",
#      15     js="index-*.js",
#      16     html='<div class="echarts-container"></div>',
#      17     isolate_styles=False,
#      18 )
#      21 class Map:
#      22     def __init__(
#      23         self, map_name: str, geo_json: dict, special_areas: dict | None = None
#      24     ) -> None:
#
# ...
